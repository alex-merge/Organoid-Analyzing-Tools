# %% [markdown]
# # Importing OAT

# %%
from OAT import *

dataset_path = r"D:\Wrk\Datasets\S0015\data\tracks"

# %% [markdown]
# ## Importing the dataset
#
# ### Looking the documentation

# %%
help(vectors.load_from_trackmate)
# Out:
# Help on function load_from_trackmate in module modules.vectors:
#
# load_from_trackmate(dirpath, rescaling=[1, 1, 1], filtering=False)
#     Load the csv files that have been generated by Trackmate.
#     The expected files are the tracks>spots csv and tracks>edges csv.
#     Returns a pandas dataframe containing coordinates,
#     displacement vectors as well as clustering information if filtering
#     have been set to True.
#
#     Parameters
#     ----------
#     dirpath : str
#         Path to the folder containing csv files.
#     rescaling : list, optional
#         Rescaling factors by axis : [x, y, z]. The default is [1, 1, 1].
#     filtering : bool, optional
#         If True, cluster the spots to remove those that are not part of the
#         organoid.
#         The default is False.
#
#     Returns
#     -------
#     df : pandas.DataFrame
#         Dataframe containing merged informations of both csv files.
#         Can be used for the next part of the pipeline.

# %% [markdown]
# ### Loading the dataset as a dataframe that works with OAT

# %%
df = vectors.load_from_trackmate(dataset_path)
df.head()
# Out:
# Opening files ... Done ! (0.02s)
# Computing displacement vectors ... Done ! (0.2s)
#      TRACK_ID  QUALITY                                              COORD  TP  \
# ID0         0      0.0                                   [0.0, 20.0, 0.0]   0
# ID1         1      0.0  [-5.893828182996233, 18.33333333333333, 5.3992...   0
# ID2         2      0.0  [0.9665277530368532, 16.666666666666668, -11.0...   0
# ID3         3      0.0       [8.04888957068736, 15.0, 10.498351140959244]   0
# ID4         4      0.0  [-14.679241943506929, 13.333333333333336, -2.5...   0
#
#     TARGET                                        DISP_VECT
# ID0   ID25   [-5.176380902050415, -0.6814834742186306, 0.0]
# ID1   ID26  [-4.5441885015497485, -2.1501281670218226, 0.0]
# ID2   ID27   [-4.346584386262093, -0.3177471050761085, 0.0]
# ID3   ID28    [-4.156544937949519, 1.5720933071569654, 0.0]
# ID4   ID29   [-2.9507375614390927, -4.253589698793087, 0.0]

# %% [markdown]
# ## Computing a full analysis on the dataset
#
# ### Looking at the documentation

# %%
help(vectors.full_analysis)
# Out:
# Help on function full_analysis in module modules.vectors:
#
# full_analysis(df)
#     Run a full analysis on the vectors of the dataset.
#
#     Parameters
#     ----------
#     df : pandas.DataFrame
#         Dataframe loaded using the provided methods of OAT.
#
#     Returns
#     -------
#     df : pandas.DataFrame
#         Dataframe with informations per spots.
#     data : pandas.DataFrame
#         Dataframe with informations per time points.

# %% [markdown]
# The full_analysis method allows you to directly compute the vector analysis on the dataframe. It can be usefull if you already have a dataframe that can work with OAT. It basically allow you to bypass the import part. By comparison, this it not possible with the basic use of OAT.
# But, you don't have much more control on parameters which can be usefull. For that, you can directly call the methods full_analysis is calling.
#
# Those methods come with a check of what data you are inputing.
#
# ### Computing the drift

# %%
data = vectors.get_drift(df)
data.head()
# Out:
# Computing drift ... Done ! (0.26s)
#       CENTROID CLUST_CENTROID DRIFT   DRIFT_VECT
# 0   [0, -1, 0]            NaN  1.73  [-1, 1, -1]
# 1  [-1, 0, -1]            NaN  1.41   [0, -1, 1]
# 2  [-1, -1, 0]            NaN  1.73   [1, 1, -1]
# 3   [0, 0, -1]            NaN  1.41   [-1, 0, 1]
# 4   [-1, 0, 0]            NaN   1.0    [1, 0, 0]

# %% [markdown]
# Here it worked because, in order to compute the drift, you only need the coordinates and the time points.
# But if you are trying to compute the angular velocity for example, it needs the rotation axis for each time points, which are not present in data for the moment.

# %%
df, data = vectors.get_angular_velocity(df, data)
# Out:
# Computing angular velocity ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 df, data = vectors.get_angular_velocity(df, data)
#
# File D:\Python\OrganoidAnalyzingTools\modules\vectors.py:440, in vectors.get_angular_velocity(df, data)
#     436 step_time = time.time()
#     437 print("Computing angular velocity ...", end = " ")
#     439 if filemanager.check_requirements(df, ["COORD", "DISP_VECT", "TP"]) and \
# --> 440     filemanager.check_requirements(data, ["V1", "V2"]):
#     442     df, data = compute.angular_velocity(df, data)
#     444 print("Done !", "("+str(round(time.time()-step_time, 2))+"s)")
#
# File D:\Python\OrganoidAnalyzingTools\modules\utils\filemanager.py:82, in filemanager.check_requirements(dataframe, columns)
#      80 if len(not_in) != 0:
#      81     col_names = ", ".join(not_in)
# ---> 82     raise AttributeError("Missing informations in the dataframe : "+col_names)
#      84 return True
#
# AttributeError: Missing informations in the dataframe : V1, V2
